# %%
import gensim
from gensim.models import KeyedVectors



logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = KeyedVectors.load_word2vec_format('../../../GoogleNews-vectors-negative300.bin.gz', binary=True, limit=100000)
# Out:
# 2017-11-26 20:34:32,917 : INFO : loading projection weights from ../../../GoogleNews-vectors-negative300.bin.gz
# 2017-11-26 20:34:36,419 : INFO : loaded (100000, 300) matrix from ../../../GoogleNews-vectors-negative300.bin.gz

# %%
print("Does it include the stop words like \'a\', \'and\', \'the\'? %d %d %d" % ('a' in model.vocab, 'and' in model.vocab, 'the' in model.vocab))
# Out:
# Does it include the stop words like 'a', 'and', 'the'? 0 0 1

# %%
vocab = model.vocab.keys()

# %%
model['students']
# Out:
# array([ 0.08203125, -0.04638672, -0.00469971,  0.3046875 ,  0.24804688,
#        -0.07080078,  0.13085938,  0.03491211, -0.01025391, -0.30078125,
#         0.16894531, -0.04199219,  0.01989746, -0.03588867, -0.04663086,
#        -0.00891113, -0.16113281, -0.06884766, -0.0402832 ,  0.00106049,
#         0.05200195,  0.2109375 ,  0.10107422, -0.04541016, -0.18847656,
#        -0.50390625, -0.15039062, -0.11035156,  0.07128906,  0.06347656,
#         0.02893066, -0.11474609, -0.23632812,  0.06933594, -0.04785156,
#        -0.03112793,  0.00337219, -0.01086426, -0.14746094,  0.10888672,
#        -0.16210938,  0.10302734, -0.04296875, -0.09375   ,  0.08837891,
#         0.01165771,  0.00430298, -0.01501465, -0.00289917,  0.13085938,
#        -0.1484375 , -0.12255859,  0.08007812,  0.0390625 ,  0.22753906,
#        -0.11767578, -0.06347656, -0.04882812, -0.07861328, -0.15722656,
#         0.10791016, -0.01300049, -0.0090332 , -0.15625   ,  0.07324219,
#         0.00964355, -0.12353516,  0.14550781,  0.14550781,  0.19335938,
#        -0.34570312, -0.00209045,  0.22851562, -0.23632812, -0.00070572,
#         0.1484375 ,  0.13574219,  0.10498047, -0.00248718,  0.08251953,
#        -0.05957031, -0.14648438, -0.1875    ,  0.20019531, -0.24414062,
#         0.14355469, -0.03710938,  0.25585938,  0.05859375,  0.03491211,
#        -0.0324707 , -0.4921875 ,  0.0480957 , -0.140625  ,  0.0625    ,
#         0.15039062,  0.04663086,  0.078125  ,  0.13085938, -0.20703125,
#         0.01556396, -0.30078125, -0.20996094, -0.265625  , -0.12597656,
#        -0.10791016,  0.07958984, -0.02075195,  0.32617188, -0.29492188,
#        -0.25976562,  0.09472656,  0.06079102,  0.04614258,  0.08642578,
#         0.00265503,  0.18945312, -0.17578125,  0.06640625, -0.02868652,
#        -0.11816406,  0.17578125,  0.01153564, -0.14160156, -0.1484375 ,
#         0.07714844, -0.13378906, -0.0177002 , -0.0189209 ,  0.265625  ,
#        -0.15820312, -0.2890625 ,  0.00224304, -0.25195312, -0.0402832 ,
#        -0.00254822,  0.25976562,  0.00494385, -0.29492188,  0.03735352,
#        -0.41601562, -0.32226562,  0.10351562, -0.02526855, -0.11914062,
#         0.2734375 ,  0.14550781,  0.03833008, -0.02233887,  0.01037598,
#         0.51953125, -0.08203125, -0.21484375, -0.12597656, -0.11669922,
#        -0.16894531, -0.04272461, -0.38476562, -0.23144531,  0.0135498 ,
#        -0.20898438,  0.16015625,  0.02770996,  0.13574219,  0.12890625,
#         0.07080078,  0.20117188,  0.16796875,  0.22949219, -0.14648438,
#        -0.03198242,  0.06787109,  0.00274658,  0.00878906,  0.12792969,
#         0.10205078, -0.07714844,  0.109375  , -0.13671875,  0.11669922,
#         0.02404785,  0.02062988, -0.01123047, -0.23828125,  0.1875    ,
#         0.09716797,  0.16015625,  0.00546265,  0.20605469,  0.11621094,
#        -0.11621094, -0.16796875, -0.05810547,  0.24316406, -0.39453125,
#        -0.14257812,  0.27539062, -0.20019531, -0.15625   , -0.04443359,
#         0.02026367, -0.01306152,  0.25      , -0.14355469, -0.24902344,
#        -0.36914062, -0.01599121, -0.24414062, -0.17089844,  0.02819824,
#         0.20214844, -0.11865234,  0.12597656, -0.17675781, -0.15527344,
#         0.17382812, -0.06054688,  0.00267029, -0.10888672, -0.01672363,
#        -0.07714844, -0.18164062,  0.03588867,  0.05859375,  0.10058594,
#         0.04248047, -0.13085938, -0.05566406,  0.12695312, -0.02026367,
#         0.04760742,  0.21679688,  0.00256348,  0.12695312,  0.20898438,
#        -0.21484375,  0.12988281, -0.02050781,  0.05566406,  0.19726562,
#         0.3125    , -0.03491211, -0.04174805, -0.08691406, -0.16308594,
#        -0.04882812, -0.2109375 ,  0.16699219, -0.16210938,  0.14746094,
#        -0.05761719,  0.05737305, -0.07421875,  0.09472656, -0.16894531,
#        -0.42773438,  0.19628906,  0.01928711, -0.05371094,  0.28515625,
#        -0.08544922, -0.03466797, -0.13378906, -0.23046875, -0.10009766,
#         0.02758789,  0.15917969,  0.17871094, -0.18261719,  0.06201172,
#        -0.02648926, -0.00958252,  0.125     ,  0.375     , -0.1015625 ,
#        -0.15820312,  0.1953125 , -0.22363281, -0.18261719, -0.21875   ,
#        -0.01647949, -0.02734375, -0.16113281,  0.21191406, -0.12011719,
#         0.07861328, -0.10839844,  0.05859375,  0.16015625,  0.16113281,
#        -0.16308594, -0.0390625 , -0.25195312, -0.10205078,  0.22949219,
#         0.23046875, -0.02832031, -0.01495361,  0.23535156, -0.01782227], dtype=float32)

# %%
# Out:
# {'"': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed610>,
#  '"Introduce': <gensim.models.keyedvectors.Vocab at 0x7f8b008edd10>,
#  '"What': <gensim.models.keyedvectors.Vocab at 0x7f8b008df9d0>,
#  '"continuity"': <gensim.models.keyedvectors.Vocab at 0x7f8b008eded0>,
#  '"dedication"': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6250>,
#  '(Motion': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6dd0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc9d0>,
#  '1993.': <gensim.models.keyedvectors.Vocab at 0x7f8b008df7d0>,
#  '1998.': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfa50>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfcd0>,
#  'And': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed8d0>,
#  'Carstairs': <gensim.models.keyedvectors.Vocab at 0x7f8b008df250>,
#  'Committee': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6f90>,
#  'Commons': <gensim.models.keyedvectors.Vocab at 0x7f8b008de650>,
#  'Every': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed950>,
#  'February': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfd50>,
#  'Finestone': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6c90>,
#  'He': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6890>,
#  'Hon.': <gensim.models.keyedvectors.Vocab at 0x7f8b008edbd0>,
#  'Honorable': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6350>,
#  'House': <gensim.models.keyedvectors.Vocab at 0x7f8b008dee90>,
#  'However,': <gensim.models.keyedvectors.Vocab at 0x7f8b008de8d0>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6710>,
#  'If': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4550>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x7f8b008dec90>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4310>,
#  'Liberal': <gensim.models.keyedvectors.Vocab at 0x7f8b008dec10>,
#  'Neither': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6390>,
#  'No': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed1d0>,
#  'Of': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfbd0>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x7f8b008deb50>,
#  'Or': <gensim.models.keyedvectors.Vocab at 0x7f8b008dea10>,
#  'Selection': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6d50>,
#  'Senate': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4210>,
#  'Senate.': <gensim.models.keyedvectors.Vocab at 0x7f8b008edf10>,
#  'Senator': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6bd0>,
#  'Senators': <gensim.models.keyedvectors.Vocab at 0x7f8b008deb90>,
#  'She': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4610>,
#  'Speaker:': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfd90>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x7f8b008dffd0>,
#  'They': <gensim.models.keyedvectors.Vocab at 0x7f8b008de590>,
#  'Three': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed2d0>,
#  'Tuesday?': <gensim.models.keyedvectors.Vocab at 0x7f8b008fca90>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcf10>,
#  'What': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcdd0>,
#  'When': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed290>,
#  'Which': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6310>,
#  'You': <gensim.models.keyedvectors.Vocab at 0x7f8b008df810>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4110>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6d10>,
#  'about,': <gensim.models.keyedvectors.Vocab at 0x7f8b008de550>,
#  'absent.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4090>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6190>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6e90>,
#  'accomplish': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6510>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6b90>,
#  'admit': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6f10>,
#  'adopt': <gensim.models.keyedvectors.Vocab at 0x7f8b008df410>,
#  'adopted.)': <gensim.models.keyedvectors.Vocab at 0x7f8b008eda50>,
#  'affairs.': <gensim.models.keyedvectors.Vocab at 0x7f8b008de790>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6c50>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed390>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcd10>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f8b008df550>,
#  'am,': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc110>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f8b008df5d0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f8b008df390>,
#  'and,': <gensim.models.keyedvectors.Vocab at 0x7f8b008ede90>,
#  'answered': <gensim.models.keyedvectors.Vocab at 0x7f8b008edc10>,
#  'anyone.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed250>,
#  'applied?': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6210>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f8b008df350>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed0d0>,
#  'association.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed510>,
#  'associations': <gensim.models.keyedvectors.Vocab at 0x7f8b008df3d0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f8b008df710>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfdd0>,
#  'attended': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6950>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6150>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x7f8b008fce90>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f8b008edd50>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed590>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f8b008edc90>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6a90>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f8b008df210>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7f8b008df4d0>,
#  'committee': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcd90>,
#  "committee's": <gensim.models.keyedvectors.Vocab at 0x7f8b008edcd0>,
#  'committee,': <gensim.models.keyedvectors.Vocab at 0x7f8b008de990>,
#  'committee.': <gensim.models.keyedvectors.Vocab at 0x7f8b008de950>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfc50>,
#  'corridors:': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc810>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6e50>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed790>,
#  'criteria': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed990>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6110>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6610>,
#  'delegations': <gensim.models.keyedvectors.Vocab at 0x7f8b02a31690>,
#  'deliberations,': <gensim.models.keyedvectors.Vocab at 0x7f8b008df950>,
#  'deprive': <gensim.models.keyedvectors.Vocab at 0x7f8b008df610>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed410>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f8b008def10>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f8b008df490>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6790>,
#  'drafted': <gensim.models.keyedvectors.Vocab at 0x7f8b008f68d0>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed150>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6c10>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6450>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed9d0>,
#  'fashionable': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfe90>,
#  'fault.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f42d0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcfd0>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6050>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f8b008edad0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f8b008fce50>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed110>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6590>,
#  'formed.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed310>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed650>,
#  'fulfilled': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6ed0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcf90>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc6d0>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x7f8b008de850>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x7f8b008de5d0>,
#  'happened.': <gensim.models.keyedvectors.Vocab at 0x7f8b008df6d0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f8b008df750>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f8b008ede10>,
#  'him.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f66d0>,
#  'him:': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6550>,
#  'honorable': <gensim.models.keyedvectors.Vocab at 0x7f8b008f45d0>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfad0>,
#  'impact.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4050>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f8b008dff10>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f8b008df790>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfd10>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfb50>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4250>,
#  'interviewed': <gensim.models.keyedvectors.Vocab at 0x7f8b008edc50>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed210>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f8b008df510>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6850>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f8b008df590>,
#  'it.': <gensim.models.keyedvectors.Vocab at 0x7f8b008de450>,
#  'it?': <gensim.models.keyedvectors.Vocab at 0x7f8b008de710>,
#  'job,': <gensim.models.keyedvectors.Vocab at 0x7f8b008f63d0>,
#  'journalists': <gensim.models.keyedvectors.Vocab at 0x7f8b008f41d0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f8b008de7d0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6d90>,
#  'leaders': <gensim.models.keyedvectors.Vocab at 0x7f8b008f60d0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6ad0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f8b008deb10>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f8b008df850>,
#  'majority': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcf50>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfa10>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f8b008f40d0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfe10>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f8b008ede50>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x7f8b008eda90>,
#  'meetings': <gensim.models.keyedvectors.Vocab at 0x7f8b008de490>,
#  'meetings.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6490>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6b50>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6a10>,
#  'men.': <gensim.models.keyedvectors.Vocab at 0x7f8b008dee10>,
#  'motion?': <gensim.models.keyedvectors.Vocab at 0x7f8b008ded90>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed910>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f8b2cdaa250>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f8b008df310>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f8b008dec50>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed890>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfc90>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x7f8b008df1d0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6b10>,
#  'nor': <gensim.models.keyedvectors.Vocab at 0x7f8b008dead0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f8b008de890>,
#  'not,': <gensim.models.keyedvectors.Vocab at 0x7f8b008df690>,
#  'now.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed5d0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6e10>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6cd0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed350>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed750>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4350>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f8b008df2d0>,
#  'others.': <gensim.models.keyedvectors.Vocab at 0x7f8b008df890>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f8b00963750>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6410>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcc90>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed190>,
#  'parliamentarians': <gensim.models.keyedvectors.Vocab at 0x7f8b008ded10>,
#  'parliamentary': <gensim.models.keyedvectors.Vocab at 0x7f8b008df910>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4390>,
#  'pleasure,': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed090>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7f8b008dff50>,
#  'practice.': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfa90>,
#  'principle': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4450>,
#  'proved.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed4d0>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed810>,
#  'quote,': <gensim.models.keyedvectors.Vocab at 0x7f8b008de690>,
#  'raise': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed690>,
#  're-join': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6090>,
#  'regard,': <gensim.models.keyedvectors.Vocab at 0x7f8b008de510>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4190>,
#  'remind': <gensim.models.keyedvectors.Vocab at 0x7f8b008f65d0>,
#  'replaced': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6810>,
#  'replacement.': <gensim.models.keyedvectors.Vocab at 0x7f8b008defd0>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcc10>,
#  'report.': <gensim.models.keyedvectors.Vocab at 0x7f8b2cdaa7d0>,
#  'reports.': <gensim.models.keyedvectors.Vocab at 0x7f8b008debd0>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x7f8b008f44d0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6690>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed3d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f8b008edb50>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7f8b008df8d0>,
#  'say?': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6990>,
#  'scheduled': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6fd0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6290>,
#  'senator': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed050>,
#  'senators': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc910>,
#  'senators,': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6f50>,
#  'senators.': <gensim.models.keyedvectors.Vocab at 0x7f8b008def90>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7f8b008de4d0>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f8b008dee50>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f8b008fca10>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6650>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7f8b008df990>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f8b008df290>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4410>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f8b008f61d0>,
#  'speak,': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4150>,
#  'speeches.': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed490>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcc50>,
#  'students,': <gensim.models.keyedvectors.Vocab at 0x7f8b008edf90>,
#  'study,': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4290>,
#  'subcommittee': <gensim.models.keyedvectors.Vocab at 0x7f8b008f62d0>,
#  'substitution.': <gensim.models.keyedvectors.Vocab at 0x7f8b008df190>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x7f8b008df650>,
#  'television.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6a50>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f8b008eddd0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f8b008edb90>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4510>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed710>,
#  'theirs.': <gensim.models.keyedvectors.Vocab at 0x7f8b008dff90>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f8b008de610>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed7d0>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f8b008edfd0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f8b008de810>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f8b008ded50>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f8b008dedd0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4490>,
#  'time.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6750>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f8b008fce10>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f8b008edb10>,
#  'translated': <gensim.models.keyedvectors.Vocab at 0x7f8b008deed0>,
#  'true,': <gensim.models.keyedvectors.Vocab at 0x7f8b008fca50>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed850>,
#  'undertake': <gensim.models.keyedvectors.Vocab at 0x7f8b008df450>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f8b008df0d0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f8b008df110>,
#  'veterans': <gensim.models.keyedvectors.Vocab at 0x7f8b008de9d0>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed450>,
#  'votes:': <gensim.models.keyedvectors.Vocab at 0x7f8b008de910>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc990>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f8b008df050>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f8b008f6910>,
#  'weeks,': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc550>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f8b008def50>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f8b008de750>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f8b008f64d0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfb10>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfb90>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfe50>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f8b008df150>,
#  'wishes': <gensim.models.keyedvectors.Vocab at 0x7f8b008f43d0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f8b008edd90>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f8b008eda10>,
#  "women's": <gensim.models.keyedvectors.Vocab at 0x7f8b008de6d0>,
#  'women.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f69d0>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f8b008edf50>,
#  'word,': <gensim.models.keyedvectors.Vocab at 0x7f8b008fc850>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x7f8b008f4590>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f8b008df090>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed6d0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f8b008fcad0>,
#  'years.': <gensim.models.keyedvectors.Vocab at 0x7f8b008f67d0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfed0>,
#  'yesterday.': <gensim.models.keyedvectors.Vocab at 0x7f8b008decd0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f8b008dfc10>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f8b008ed550>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f8b008dea90>}
